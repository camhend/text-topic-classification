# %%
import numpy as np
import pandas as pd

# %% [raw]
# data_dir = '/home/henderc7/cs571/202540_data571_final_project_group16/proj_data/task1_topics'
# trainX = np.loadtxt(f'{data_dir}/train.sparseX', dtype=int32)
# trainX = pd.Dataframe(trainX)
# devX = np.loadtxt(f'{data_dir}/dev.sparseX'}, dtype=int32)
# devX = pd.Dataframe(devX)
